# %% [markdown]
# # .txt 라벨 변환

# %%
import os
import json
from glob import glob
from PIL import Image

# 클래스 정의 (COCO + rocar 포함, 총 81개)
class_names = [
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat',
    'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench',
    'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe',
    'backpack', 'umbrella', 'handbag', 'tie', 'suitcase',
    'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket',
    'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
    'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush',
    'roscar'
]

# 디렉토리 경로 설정
json_dir = "/home/usou/Downloads/saved_frames/0_50/"
output_txt_dir = "/home/usou/Downloads/saved_frames/0_50/"
os.makedirs(output_txt_dir, exist_ok=True)

# 변환 실행
json_files = glob(os.path.join(json_dir, "*.json"))
for json_file in json_files:
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)

        img_path = json_file.replace(".json", ".jpg")
        img = Image.open(img_path)
        w, h = img.size

        txt_path = os.path.join(output_txt_dir, os.path.basename(json_file).replace(".json", ".txt"))
        with open(txt_path, 'w') as out_file:
            for shape in data['shapes']:
                label = shape['label']
                if label not in class_names:
                    continue
                class_id = class_names.index(label)

                x_list = [pt[0] for pt in shape['points']]
                y_list = [pt[1] for pt in shape['points']]

                x_center = (min(x_list) + max(x_list)) / 2 / w
                y_center = (min(y_list) + max(y_list)) / 2 / h
                width = (max(x_list) - min(x_list)) / w
                height = (max(y_list) - min(y_list)) / h

                out_file.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

        print(f"✅ 변환 완료: {os.path.basename(json_file)}")

    except Exception as e:
        print(f"❌ 변환 실패: {os.path.basename(json_file)} | 에러: {e}")
# Out:
# ✅ 변환 완료: 0_50_00132.json
# ✅ 변환 완료: 0_50_00098.json
# ✅ 변환 완료: 0_50_00013.json
# ✅ 변환 완료: 0_50_00082.json
# ✅ 변환 완료: 0_50_00155.json
# ✅ 변환 완료: 0_50_00032.json
# ✅ 변환 완료: 0_50_00048.json
# ✅ 변환 완료: 0_50_00134.json
# ✅ 변환 완료: 0_50_00086.json
# ✅ 변환 완료: 0_50_00171.json
# ✅ 변환 완료: 0_50_00114.json
# ✅ 변환 완료: 0_50_00055.json
# ✅ 변환 완료: 0_50_00030.json
# ✅ 변환 완료: 0_50_00193.json
# ✅ 변환 완료: 0_50_00159.json
# ✅ 변환 완료: 0_50_00095.json
# ✅ 변환 완료: 0_50_00104.json
# ✅ 변환 완료: 0_50_00038.json
# ✅ 변환 완료: 0_50_00099.json
# ✅ 변환 완료: 0_50_00025.json
# ✅ 변환 완료: 0_50_00138.json
# ✅ 변환 완료: 0_50_00014.json
# ✅ 변환 완료: 0_50_00177.json
# ✅ 변환 완료: 0_50_00047.json
# ✅ 변환 완료: 0_50_00147.json
# ✅ 변환 완료: 0_50_00156.json
# ✅ 변환 완료: 0_50_00003.json
# ✅ 변환 완료: 0_50_00084.json
# ✅ 변환 완료: 0_50_00020.json
# ✅ 변환 완료: 0_50_00008.json
# ✅ 변환 완료: 0_50_00089.json
# ✅ 변환 완료: 0_50_00181.json
# ✅ 변환 완료: 0_50_00046.json
# ✅ 변환 완료: 0_50_00161.json
# ✅ 변환 완료: 0_50_00065.json
# ✅ 변환 완료: 0_50_00105.json
# ✅ 변환 완료: 0_50_00167.json
# ✅ 변환 완료: 0_50_00052.json
# ✅ 변환 완료: 0_50_00015.json
# ✅ 변환 완료: 0_50_00129.json
# ✅ 변환 완료: 0_50_00125.json
# ✅ 변환 완료: 0_50_00150.json
# ✅ 변환 완료: 0_50_00176.json
# ✅ 변환 완료: 0_50_00136.json
# ✅ 변환 완료: 0_50_00058.json
# ✅ 변환 완료: 0_50_00051.json
# ✅ 변환 완료: 0_50_00056.json
# ✅ 변환 완료: 0_50_00076.json
# ✅ 변환 완료: 0_50_00169.json
# ✅ 변환 완료: 0_50_00053.json
# ✅ 변환 완료: 0_50_00131.json
# ✅ 변환 완료: 0_50_00093.json
# ✅ 변환 완료: 0_50_00062.json
# ✅ 변환 완료: 0_50_00170.json
# ✅ 변환 완료: 0_50_00113.json
# ✅ 변환 완료: 0_50_00189.json
# ✅ 변환 완료: 0_50_00135.json
# ✅ 변환 완료: 0_50_00192.json
# ✅ 변환 완료: 0_50_00103.json
# ✅ 변환 완료: 0_50_00122.json
# ✅ 변환 완료: 0_50_00004.json
# ✅ 변환 완료: 0_50_00081.json
# ✅ 변환 완료: 0_50_00166.json
# ✅ 변환 완료: 0_50_00163.json
# ✅ 변환 완료: 0_50_00001.json
# ✅ 변환 완료: 0_50_00184.json
# ✅ 변환 완료: 0_50_00183.json
# ✅ 변환 완료: 0_50_00085.json
# ✅ 변환 완료: 0_50_00187.json
# ✅ 변환 완료: 0_50_00182.json
# ✅ 변환 완료: 0_50_00128.json
# ✅ 변환 완료: 0_50_00033.json
# ✅ 변환 완료: 0_50_00180.json
# ✅ 변환 완료: 0_50_00057.json
# ✅ 변환 완료: 0_50_00069.json
# ✅ 변환 완료: 0_50_00196.json
# ✅ 변환 완료: 0_50_00043.json
# ✅ 변환 완료: 0_50_00045.json
# ✅ 변환 완료: 0_50_00023.json
# ✅ 변환 완료: 0_50_00074.json
# ✅ 변환 완료: 0_50_00087.json
# ✅ 변환 완료: 0_50_00006.json
# ✅ 변환 완료: 0_50_00174.json
# ✅ 변환 완료: 0_50_00078.json
# ✅ 변환 완료: 0_50_00106.json
# ✅ 변환 완료: 0_50_00158.json
# ✅ 변환 완료: 0_50_00061.json
# ✅ 변환 완료: 0_50_00088.json
# ✅ 변환 완료: 0_50_00036.json
# ✅ 변환 완료: 0_50_00007.json
# ✅ 변환 완료: 0_50_00165.json
# ✅ 변환 완료: 0_50_00090.json
# ✅ 변환 완료: 0_50_00024.json
# ✅ 변환 완료: 0_50_00162.json
# ✅ 변환 완료: 0_50_00198.json
# ✅ 변환 완료: 0_50_00000.json
# ✅ 변환 완료: 0_50_00197.json
# ✅ 변환 완료: 0_50_00140.json
# ✅ 변환 완료: 0_50_00118.json
# ✅ 변환 완료: 0_50_00091.json
# ✅ 변환 완료: 0_50_00168.json
# ✅ 변환 완료: 0_50_00005.json
# ✅ 변환 완료: 0_50_00019.json
# ✅ 변환 완료: 0_50_00044.json
# ✅ 변환 완료: 0_50_00012.json
# ✅ 변환 완료: 0_50_00010.json
# ✅ 변환 완료: 0_50_00160.json
# ✅ 변환 완료: 0_50_00164.json
# ✅ 변환 완료: 0_50_00141.json
# ✅ 변환 완료: 0_50_00026.json
# ✅ 변환 완료: 0_50_00027.json
# ✅ 변환 완료: 0_50_00064.json
# ✅ 변환 완료: 0_50_00139.json
# ✅ 변환 완료: 0_50_00142.json
# ✅ 변환 완료: 0_50_00083.json
# ✅ 변환 완료: 0_50_00037.json
# ✅ 변환 완료: 0_50_00112.json
# ✅ 변환 완료: 0_50_00022.json
# ✅ 변환 완료: 0_50_00117.json
# ✅ 변환 완료: 0_50_00145.json
# ✅ 변환 완료: 0_50_00186.json
# ✅ 변환 완료: 0_50_00101.json
# ✅ 변환 완료: 0_50_00068.json
# ✅ 변환 완료: 0_50_00121.json
# ✅ 변환 완료: 0_50_00066.json
# ✅ 변환 완료: 0_50_00143.json
# ✅ 변환 완료: 0_50_00071.json
# ✅ 변환 완료: 0_50_00133.json
# ✅ 변환 완료: 0_50_00092.json
# ✅ 변환 완료: 0_50_00079.json
# ✅ 변환 완료: 0_50_00080.json
# ✅ 변환 완료: 0_50_00107.json
# ✅ 변환 완료: 0_50_00194.json
# ✅ 변환 완료: 0_50_00127.json
# ✅ 변환 완료: 0_50_00072.json
# ✅ 변환 완료: 0_50_00031.json
# ✅ 변환 완료: 0_50_00018.json
# ✅ 변환 완료: 0_50_00124.json
# ✅ 변환 완료: 0_50_00017.json
# ✅ 변환 완료: 0_50_00009.json
# ✅ 변환 완료: 0_50_00151.json
# ✅ 변환 완료: 0_50_00191.json
# ✅ 변환 완료: 0_50_00190.json
# ✅ 변환 완료: 0_50_00115.json
# ✅ 변환 완료: 0_50_00070.json
# ✅ 변환 완료: 0_50_00039.json
# ✅ 변환 완료: 0_50_00040.json
# ✅ 변환 완료: 0_50_00002.json
# ✅ 변환 완료: 0_50_00188.json
# ✅ 변환 완료: 0_50_00195.json
# ✅ 변환 완료: 0_50_00097.json
# ✅ 변환 완료: 0_50_00110.json
# ✅ 변환 완료: 0_50_00035.json
# ✅ 변환 완료: 0_50_00073.json
# ✅ 변환 완료: 0_50_00029.json
# ✅ 변환 완료: 0_50_00116.json
# ✅ 변환 완료: 0_50_00049.json
# ✅ 변환 완료: 0_50_00109.json
# ✅ 변환 완료: 0_50_00199.json
# ✅ 변환 완료: 0_50_00094.json
# ✅ 변환 완료: 0_50_00175.json
# ✅ 변환 완료: 0_50_00123.json
# ✅ 변환 완료: 0_50_00111.json
# ✅ 변환 완료: 0_50_00178.json
# ✅ 변환 완료: 0_50_00059.json
# ✅ 변환 완료: 0_50_00173.json
# ✅ 변환 완료: 0_50_00067.json
# ✅ 변환 완료: 0_50_00100.json
# ✅ 변환 완료: 0_50_00154.json
# ✅ 변환 완료: 0_50_00050.json
# ✅ 변환 완료: 0_50_00172.json
# ✅ 변환 완료: 0_50_00077.json
# ✅ 변환 완료: 0_50_00153.json
# ✅ 변환 완료: 0_50_00041.json
# ✅ 변환 완료: 0_50_00011.json
# ✅ 변환 완료: 0_50_00130.json
# ✅ 변환 완료: 0_50_00152.json
# ✅ 변환 완료: 0_50_00016.json
# ✅ 변환 완료: 0_50_00146.json
# ✅ 변환 완료: 0_50_00144.json
# ✅ 변환 완료: 0_50_00060.json
# ✅ 변환 완료: 0_50_00179.json
# ✅ 변환 완료: 0_50_00157.json
# ✅ 변환 완료: 0_50_00119.json
# ✅ 변환 완료: 0_50_00063.json
# ✅ 변환 완료: 0_50_00137.json
# ✅ 변환 완료: 0_50_00185.json
# ✅ 변환 완료: 0_50_00108.json
# ✅ 변환 완료: 0_50_00034.json
# ✅ 변환 완료: 0_50_00054.json
# ✅ 변환 완료: 0_50_00120.json
# ✅ 변환 완료: 0_50_00148.json
# ✅ 변환 완료: 0_50_00149.json
# ✅ 변환 완료: 0_50_00126.json
# ✅ 변환 완료: 0_50_00021.json
# ✅ 변환 완료: 0_50_00096.json
# ✅ 변환 완료: 0_50_00075.json
# ✅ 변환 완료: 0_50_00028.json
# ✅ 변환 완료: 0_50_00102.json
# ✅ 변환 완료: 0_50_00042.json

# %% [markdown]
# #  data.yaml 파일 생성 (81 클래스)

# %%
import yaml

# 저장할 yaml 경로
yaml_save_path = "/home/usou/dev_ws/underRos/ros-repo-3/AI/src/data.yaml"  # 실제 학습할 data.yaml 위치로 수정하세요

# class name 목록 (COCO + rocar)
class_names = [
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat',
    'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench',
    'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe',
    'backpack', 'umbrella', 'handbag', 'tie', 'suitcase',
    'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket',
    'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
    'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush',
    'roscar'
]

data_yaml = {
    "path": "/home/usou/yolo_dataset",  # 전체 dataset root
    "train": "images/train",
    "val": "images/val",
    "nc": len(class_names),
    "names": class_names
}

with open(yaml_save_path, 'w') as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

print(f"✅ data.yaml 저장 완료: {yaml_save_path}")
# Out:
# ✅ data.yaml 저장 완료: /home/usou/dev_ws/underRos/ros-repo-3/AI/src/data.yaml

# %% [markdown]
# # 3단계: 이미지 및 라벨 파일 train/val 분할

# %%
import shutil
import random
from glob import glob

# YOLO 라벨 및 이미지 기준 폴더
image_dir = "/home/usou/Downloads/saved_frames/0_50/"            # .jpg 이미지 폴더
label_dir = "/home/usou/Downloads/saved_frames/0_50/"       # YOLO .txt 라벨 폴더
dataset_root = "/home/usou/yolo_dataset"

# 비율 설정
train_ratio = 0.9

# 이미지 파일 리스트 (라벨 있는 것만 대상)
image_paths = sorted(glob(os.path.join(image_dir, "*.jpg")))
labeled_images = [p for p in image_paths if os.path.exists(os.path.join(label_dir, os.path.basename(p).replace(".jpg", ".txt")))]

# 분할
random.shuffle(labeled_images)
split_idx = int(len(labeled_images) * train_ratio)
train_imgs = labeled_images[:split_idx]
val_imgs = labeled_images[split_idx:]

# 디렉토리 생성
for subdir in ["images/train", "images/val", "labels/train", "labels/val"]:
    os.makedirs(os.path.join(dataset_root, subdir), exist_ok=True)

# 파일 복사
def copy_files(img_list, img_dst, lbl_dst):
    for img_path in img_list:
        base = os.path.basename(img_path)
        label_path = os.path.join(label_dir, base.replace(".jpg", ".txt"))
        shutil.copy(img_path, os.path.join(img_dst, base))
        shutil.copy(label_path, os.path.join(lbl_dst, base.replace(".jpg", ".txt")))

copy_files(train_imgs,
           os.path.join(dataset_root, "images/train"),
           os.path.join(dataset_root, "labels/train"))

copy_files(val_imgs,
           os.path.join(dataset_root, "images/val"),
           os.path.join(dataset_root, "labels/val"))

print(f"✅ train/val 분할 완료: 총 {len(train_imgs)} train, {len(val_imgs)} val")
# Out:
# ✅ train/val 분할 완료: 총 180 train, 20 val

# %% [markdown]
# 4단계: YOLO 학습 명령어 (터미널에서 실행)
# yolo detect train model=yolov8n.pt data=/home/usou/yolo_dataset/data.yaml epochs=100 imgsz=640

# %%
import os
import random
import shutil
from glob import glob
from tqdm import tqdm

image_dir = "/home/usou/Downloads/saved_frames/0_50/"
label_dir = "/home/usou/Downloads/saved_frames/0_50/"
dataset_root = "/home/usou/yolo_dataset"

train_ratio = 0.9

# 1. 라벨 있는 이미지만 필터링
image_paths = sorted(glob(os.path.join(image_dir, "*.jpg")))
labeled_images = []

for img_path in tqdm(image_paths):
    base = os.path.basename(img_path).replace(".jpg", ".txt")
    label_path = os.path.join(label_dir, base)

    if os.path.exists(label_path) and os.path.getsize(label_path) > 0:
        labeled_images.append(img_path)

print(f"✅ 유효한 라벨 보유 이미지 수: {len(labeled_images)}")

# 2. 분할
random.shuffle(labeled_images)
split_idx = int(len(labeled_images) * train_ratio)
train_imgs = labeled_images[:split_idx]
val_imgs = labeled_images[split_idx:]

# 3. 디렉토리 생성
for sub in ["images/train", "images/val", "labels/train", "labels/val"]:
    os.makedirs(os.path.join(dataset_root, sub), exist_ok=True)

# 4. 복사
def copy_files(img_list, img_dst, lbl_dst):
    for img_path in tqdm(img_list):
        base = os.path.basename(img_path)
        label_path = os.path.join(label_dir, base.replace(".jpg", ".txt"))

        shutil.copy(img_path, os.path.join(img_dst, base))
        shutil.copy(label_path, os.path.join(lbl_dst, base.replace(".jpg", ".txt")))

copy_files(train_imgs,
           os.path.join(dataset_root, "images/train"),
           os.path.join(dataset_root, "labels/train"))

copy_files(val_imgs,
           os.path.join(dataset_root, "images/val"),
           os.path.join(dataset_root, "labels/val"))

print(f"🎯 최종 분할 결과: train={len(train_imgs)} val={len(val_imgs)}")
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 150657.47it/s]
# ✅ 유효한 라벨 보유 이미지 수: 0
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 🎯 최종 분할 결과: train=0 val=0
